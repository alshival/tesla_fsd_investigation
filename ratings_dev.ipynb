# %%
import pandas as pd
import requests
import time
from datetime import date, datetime

from config import *

########################################
# Main function to download complaints
########################################
# Function to get complaints from NHTSA API
import requests
from requests.exceptions import Timeout, RequestException
import time

# Get rating years
url = 'https://api.nhtsa.gov/SafetyRatings'
response = requests.get(url).json()
rating_years = pd.DataFrame(response['Results'])
db = pg_connect()
rating_years.to_sql('ratings_years',db,index=False,if_exists='replace')
db.dispose()
# Out:
# Configuration loaded successfully.

# %%
# Get makes for ratings year
def get_makes_for_rating_year(year,retries=3, timeout=30):
    url = f'https://api.nhtsa.gov/SafetyRatings/modelyear/{year}'
    attempt = 0
    while attempt < retries:
            try:
                # Make the GET request to the NHTSA API with a timeout
                response = requests.get(url, timeout=timeout)
                
                # Check if the request was successful
                if response.status_code == 200:
                    # Return the JSON response
                    return response.json().get('Results', [])
                elif response.status_code == 400:
                    return None
                else:
                    # Return an error message
                    return None
            except Timeout:
                # Handle timeout exception
                attempt += 1
                print(f"Attempt {attempt} timed out. Retrying...")
                time.sleep(5)  # wait before retrying
            except RequestException as e:
                attempt += 1
                # Handle other request exceptions
                print(f"Request failed: {e}")
                time.sleep(5)
            except Exception as e:
                attempt += 1
                print(f"Request failed: {e}")
                time.sleep(5)

    # If all attempts fail, return None
    print("All attempts to contact the API have failed.")
    return None

# download makes for rating years
db = pg_connect()
for year in rating_years['ModelYear'][rating_years['ModelYear']>=2019]:
    temp =get_makes_for_rating_year(year)
    temp_df = pd.DataFrame(temp)
    temp_df.to_sql('ratings_makes_for_years',db,index=False,if_exists='append')
db.dispose()

pg_clean_table('ratings_makes_for_years')
# Out:
# Duplicates removed from ratings_makes_for_years

# %%
# Get makes for ratings year
def get_models_for_make_rating_years(year,make,retries=3, timeout=30):
    url = f'https://api.nhtsa.gov/SafetyRatings/modelyear/{year}/make/{make}'
    attempt = 0
    while attempt < retries:
            try:
                # Make the GET request to the NHTSA API with a timeout
                response = requests.get(url, timeout=timeout)
                
                # Check if the request was successful
                if response.status_code == 200:
                    # Return the JSON response
                    return response.json().get('Results', [])
                elif response.status_code == 400:
                    return None
                else:
                    # Return an error message
                    return None
            except Timeout:
                # Handle timeout exception
                attempt += 1
                print(f"Attempt {attempt} timed out. Retrying...")
                time.sleep(5)  # wait before retrying
            except RequestException as e:
                attempt += 1
                # Handle other request exceptions
                print(f"Request failed: {e}")
                time.sleep(5)
            except Exception as e:
                attempt += 1
                print(f"Request failed: {e}")
                time.sleep(5)

    # If all attempts fail, return None
    print("All attempts to contact the API have failed.")
    return None
    

# Create table to track model updates
if 'ratings_model_download_tracker' not in pg_tables():
    query = """
create table ratings_model_download_tracker as
select
	*,
	CURRENT_TIMESTAMP - interval '1000 years' as models_last_updated,
    0 as models_downloaded
from ratings_makes_for_years
"""
    pg_execute(query)
    print("ratings_model_download_tracker table created")

# Update model download tracker
pg_execute("""
INSERT INTO ratings_model_download_tracker
select distinct on ("ModelYear","Make","VehicleId")
	"ModelYear",
	"Make",
    "VehicleId",
	CURRENT_TIMESTAMP - interval '1000 years' as models_last_updated,
    0 as models_downloaded
from ratings_makes_for_years
where ("ModelYear","Make","VehicleId") not in (select "ModelYear","Make","VehicleId" from ratings_model_download_tracker)
""")
print("ratings_model_download_tracker updated")
# Out:
# ratings_model_download_tracker updated

# %%
ratings_model_download_tracker = pg_query("""
select
    *
from ratings_model_download_tracker
where models_last_updated < current_date - interval '15 days'
and "ModelYear"::int >= extract(year from current_date) - 5
""")

db = pg_connect()
for _,row in ratings_model_download_tracker.iterrows():
    temp = get_models_for_make_rating_years(row['ModelYear'],row['Make'])
    temp_df = pd.DataFrame(temp)
    temp_df.to_sql('ratings_models',db,index=False,if_exists='append')
    time.sleep(1)
    with db.connect() as connection:
        query = text("""
                   update ratings_model_download_tracker
                   set models_last_updated = current_timestamp, models_downloaded = :a
                   where "ModelYear"::int = :x and "Make" = :y and "VehicleId" = :z
                   """)
        connection.execute(query,{'a':len(temp_df),'x':row['ModelYear'],'y':row['Make'],'z':row['VehicleId']})
        connection.commit()
    print(f'rating models for {row['ModelYear']} {row['Make']} updated')
db.dispose()

pg_clean_table('ratings_models')
# Out:
# rating models for 2019 ACURA updated
# rating models for 2019 ALFA ROMEO updated
# rating models for 2019 AUDI updated
# rating models for 2019 BENTLEY updated
# rating models for 2019 BMW updated
# rating models for 2019 BUICK updated
# rating models for 2019 CADILLAC updated
# rating models for 2019 CHEVROLET updated
# rating models for 2019 CHRYSLER updated
# rating models for 2019 DODGE updated
# rating models for 2019 FIAT updated
# rating models for 2019 FORD updated
# rating models for 2019 FREIGHTLINER updated
# rating models for 2019 GENESIS updated
# rating models for 2019 GMC updated
# rating models for 2019 HONDA updated
# rating models for 2019 HYUNDAI updated
# rating models for 2019 INFINITI updated
# rating models for 2019 JAGUAR updated
# rating models for 2019 JEEP updated
# rating models for 2019 KIA updated
# rating models for 2019 LAND ROVER updated
# rating models for 2019 LEXUS updated
# rating models for 2019 LINCOLN updated
# rating models for 2019 MASERATI updated
# rating models for 2019 MAZDA updated
# rating models for 2019 MERCEDES-BENZ updated
# rating models for 2019 MERCEDES-MAYBACH updated
# rating models for 2019 MINI updated
# rating models for 2019 MITSUBISHI updated
# rating models for 2019 NISSAN updated
# rating models for 2019 PORSCHE updated
# rating models for 2019 RAM updated
# rating models for 2019 ROLLS-ROYCE updated
# rating models for 2019 SMART updated
# rating models for 2019 STI updated
# rating models for 2019 SUBARU updated
# rating models for 2019 TESLA updated
# rating models for 2019 TOYOTA updated
# rating models for 2023 VOLVO updated
# rating models for 2019 VOLKSWAGEN updated
# rating models for 2019 VOLVO updated
# rating models for 2020 ACURA updated
# rating models for 2020 ALFA updated
# rating models for 2020 AUDI updated
# rating models for 2020 BENTLEY updated
# rating models for 2020 BMW updated
# rating models for 2020 BUICK updated
# rating models for 2020 CADILLAC updated
# rating models for 2020 CHEVROLET updated
# rating models for 2020 CHRYSLER updated
# rating models for 2020 DODGE updated
# rating models for 2020 FIAT updated
# rating models for 2020 FORD updated
# rating models for 2020 FREIGHTLINER updated
# rating models for 2020 GENESIS updated
# rating models for 2020 GMC updated
# rating models for 2020 HONDA updated
# rating models for 2020 HYUNDAI updated
# rating models for 2020 INFINITI updated
# rating models for 2020 JAGUAR updated
# rating models for 2020 JEEP updated
# rating models for 2020 KIA updated
# rating models for 2020 LAND ROVER updated
# rating models for 2020 LEXUS updated
# rating models for 2020 LINCOLN updated
# rating models for 2020 MAZDA updated
# rating models for 2020 MERCEDES-BENZ updated
# rating models for 2020 MERCEDES-MAYBACH updated
# rating models for 2020 MINI updated
# rating models for 2020 MITSUBISHI updated
# rating models for 2020 NISSAN updated
# rating models for 2020 PORSCHE updated
# rating models for 2020 RAM updated
# rating models for 2020 ROLLS-ROYCE updated
# rating models for 2020 SUBARU updated
# rating models for 2020 TESLA updated
# rating models for 2020 TOYOTA updated
# rating models for 2020 VOLKSWAGEN updated
# rating models for 2020 VOLVO updated
# rating models for 2021 ACURA updated
# rating models for 2021 ALFA updated
# rating models for 2021 AUDI updated
# rating models for 2021 BENTLEY updated
# rating models for 2021 BMW updated
# rating models for 2021 BUICK updated
# rating models for 2021 CADILLAC updated
# rating models for 2021 CHEVROLET updated
# rating models for 2021 CHRYSLER updated
# rating models for 2021 DODGE updated
# rating models for 2021 FIAT updated
# rating models for 2021 FORD updated
# rating models for 2021 FREIGHTLINER updated
# rating models for 2021 GENESIS updated
# rating models for 2021 GMC updated
# rating models for 2021 HONDA updated
# rating models for 2021 HYUNDAI updated
# rating models for 2021 INFINITI updated
# rating models for 2021 JAGUAR updated
# rating models for 2021 JEEP updated
# rating models for 2021 KIA updated
# rating models for 2021 LAND ROVER updated
# rating models for 2021 LEXUS updated
# rating models for 2021 LINCOLN updated
# rating models for 2021 MAZDA updated
# rating models for 2021 MERCEDES-BENZ updated
# rating models for 2021 MINI updated
# rating models for 2021 MITSUBISHI updated
# rating models for 2021 NISSAN updated
# rating models for 2021 PORSCHE updated
# rating models for 2021 RAM updated
# rating models for 2021 ROLLS-ROYCE updated
# rating models for 2021 SUBARU updated
# rating models for 2021 TESLA updated
# rating models for 2021 TOYOTA updated
# rating models for 2021 VOLKSWAGEN updated
# rating models for 2021 VOLVO updated
# rating models for 2023 ACURA updated
# rating models for 2023 ALFA updated
# rating models for 2023 AUDI updated
# rating models for 2023 BENTLEY updated
# rating models for 2023 BMW updated
# rating models for 2023 BRIGHTDROP updated
# rating models for 2023 BUICK updated
# rating models for 2023 CADILLAC updated
# rating models for 2023 CHEVROLET updated
# rating models for 2023 CHRYSLER updated
# rating models for 2023 DODGE updated
# rating models for 2023 FIAT updated
# rating models for 2023 FORD updated
# rating models for 2023 GENESIS updated
# rating models for 2023 GMC updated
# rating models for 2023 HONDA updated
# rating models for 2023 HYUNDAI updated
# rating models for 2023 INFINITI updated
# rating models for 2023 JAGUAR updated
# rating models for 2023 JEEP updated
# rating models for 2023 KIA updated
# rating models for 2023 LAND ROVER updated
# rating models for 2023 LEXUS updated
# rating models for 2023 LINCOLN updated
# rating models for 2023 LUCID updated
# rating models for 2023 MAZDA updated
# rating models for 2023 MERCEDES-BENZ updated
# rating models for 2023 MINI updated
# rating models for 2023 MITSUBISHI updated
# rating models for 2023 NISSAN updated
# rating models for 2023 POLESTAR updated
# rating models for 2023 PORSCHE updated
# rating models for 2023 RAM updated
# rating models for 2023 RIVIAN updated
# rating models for 2023 ROLLS-ROYCE updated
# rating models for 2023 SUBARU updated
# rating models for 2023 TESLA updated
# rating models for 2023 TOYOTA updated
# rating models for 2023 VOLKSWAGEN updated
# rating models for 2024 ACURA updated
# rating models for 2024 ALFA updated
# rating models for 2024 AUDI updated
# rating models for 2024 BENTLEY updated
# rating models for 2024 BMW updated
# rating models for 2024 BRIGHTDROP updated
# rating models for 2024 BUICK updated
# rating models for 2024 CADILLAC updated
# rating models for 2024 CHEVROLET updated
# rating models for 2024 CHRYSLER updated
# rating models for 2024 DODGE updated
# rating models for 2024 FIAT updated
# rating models for 2024 FORD updated
# rating models for 2024 GENESIS updated
# rating models for 2024 GMC updated
# rating models for 2024 HONDA updated
# rating models for 2024 HYUNDAI updated
# rating models for 2024 INFINITI updated
# rating models for 2024 JAGUAR updated
# rating models for 2024 JEEP updated
# rating models for 2024 KIA updated
# rating models for 2024 LAND ROVER updated
# rating models for 2024 LEXUS updated
# rating models for 2024 LINCOLN updated
# rating models for 2024 LUCID updated
# rating models for 2024 MAZDA updated
# rating models for 2024 MERCEDES-BENZ updated
# rating models for 2024 MERCEDES-MAYBACH updated
# rating models for 2024 MINI updated
# rating models for 2024 MITSUBISHI updated
# rating models for 2024 NISSAN updated
# rating models for 2024 POLESTAR updated
# rating models for 2024 PORSCHE updated
# rating models for 2024 RAM updated
# rating models for 2024 RIVIAN updated
# rating models for 2024 ROLLS-ROYCE updated
# rating models for 2024 SUBARU updated
# rating models for 2024 TESLA updated
# rating models for 2024 TOYOTA updated
# rating models for 2024 VINFAST updated
# rating models for 2024 VOLKSWAGEN updated
# rating models for 2024 VOLVO updated
# rating models for 2025 ACURA updated
# rating models for 2025 AUDI updated
# rating models for 2025 FORD updated
# rating models for 2025 HONDA updated
# rating models for 2025 KIA updated
# rating models for 2025 LEXUS updated
# rating models for 2025 LINCOLN updated
# rating models for 2025 RAM updated
# rating models for 2025 SUBARU updated
# Duplicates removed from ratings_models

# %%
if 'ratings_download_tracker' not in pg_tables():
    query = """
create table ratings_model_variants_download_tracker as
select
	*,
	CURRENT_TIMESTAMP - interval '1000 years' as variants_last_updated,
    0 as total_variants
from ratings_models
"""
    pg_execute(query)
    print("ratings_model_variants_download_tracker table created")

# Update complaint download tracker
pg_execute("""
INSERT INTO ratings_model_variants_download_tracker
select distinct on ("ModelYear","Make","Model","VehicleId")
	"ModelYear",
	"Make",
    "Model",
    "VehicleId",     
	CURRENT_TIMESTAMP - interval '1000 years' as variants_last_updated,
    0 as total_variants
from ratings_models
where ("ModelYear","Make","Model","VehicleId") not in (select "ModelYear","Make","Model","VehicleId" from ratings_model_variants_download_tracker)
""")
# Out:
# ratings_model_variants_download_tracker table created
# 'done'

# %%
# Get makes for ratings year
def get_model_variants(year,make,model,retries=3, timeout=30):
    url = f'https://api.nhtsa.gov/SafetyRatings/modelyear/{year}/make/{make}/model/{model}'
    attempt = 0
    while attempt < retries:
            try:
                # Make the GET request to the NHTSA API with a timeout
                response = requests.get(url, timeout=timeout)
                
                # Check if the request was successful
                if response.status_code == 200:
                    # Return the JSON response
                    return response.json().get('Results', [])
                elif response.status_code == 400:
                    return None
                else:
                    # Return an error message
                    return None
            except Timeout:
                # Handle timeout exception
                attempt += 1
                print(f"Attempt {attempt} timed out. Retrying...")
                time.sleep(5)  # wait before retrying
            except RequestException as e:
                attempt += 1
                # Handle other request exceptions
                print(f"Request failed: {e}")
                time.sleep(5)
            except Exception as e:
                attempt += 1
                print(f"Request failed: {e}")
                time.sleep(5)

    # If all attempts fail, return None
    print("All attempts to contact the API have failed.")
    return None

# %%
if 'ratings_download_tracker' in pg_tables():
    variants_download_tracker = pg_query("""
    select
        *
    from ratings_model_variants_download_tracker
    where variants_last_updated < current_date - interval '7 days'
    and "ModelYear" >= extract(year from current_date)
    and "VehicleId" not in (select "VehicleId" from ratings_download_tracker where rated = true)
    """)
else: 
    variants_download_tracker = pg_query("""
    select
        *
    from ratings_model_variants_download_tracker
    where variants_last_updated < current_date - interval '7 days'
    and "ModelYear" >= extract(year from current_date)
    """)

db = pg_connect()
for _, row in variants_download_tracker.iterrows():
    # Download variants
    variants = get_model_variants(row['ModelYear'],row['Make'],row['Model'])
    variants_df = pd.DataFrame(variants)
    variants_df['ModelYear'] = row['ModelYear']
    variants_df['Make'] = row['Make']
    variants_df['Model'] = row['Model']
    variants_df.to_sql('ratings_models_variants',db,index=False,if_exists='append')
    # Download rating for each model variant
    with db.connect() as connection:
        query = text("""
        update ratings_model_variants_download_tracker
        set variants_last_updated = current_timestamp, total_variants = :a
        where "ModelYear" = :x and "Make" = :y and "Model" = :z and "VehicleId" = :w
        """)
        connection.execute(query,{'a':variants_df.shape[0],'x':row['ModelYear'],'y':row['Make'],'z':row['Model'],'w':row['VehicleId']})
        connection.commit()
    print(f'{row["ModelYear"]} {row['Make']} {row["Model"]} variants downloaded')
    time.sleep(1)
pg_clean_table('ratings_models_variants')
# Out:
# 2024 CADILLAC XT5 variants downloaded
# 2024 CADILLAC CT5-V variants downloaded
# 2024 AUDI SQ7 variants downloaded
# 2024 MERCEDES-BENZ MERCEDES-BENZ ESPRINTER (SO) variants downloaded
# 2024 BUICK ENVISTA variants downloaded
# 2024 FORD F-250 (CREW CAB) variants downloaded
# 2024 FORD TRANSIT VAN BEV variants downloaded
# 2024 BMW M4 CONVERTIBLE variants downloaded
# 2024 BMW X6 M variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 2500 12 PASSENGER VAN variants downloaded
# 2024 FORD EXPLORER variants downloaded
# 2024 JEEP WAGONEER variants downloaded
# 2024 PORSCHE TAYCAN GTS SPORT TURISMO variants downloaded
# 2024 BENTLEY FLYING SPUR HYBRID variants downloaded
# 2024 PORSCHE 718 CAYMAN GTS 4.0 variants downloaded
# 2024 CHEVROLET CORVETTE variants downloaded
# 2024 MITSUBISHI MIRAGE G4 variants downloaded
# 2024 MERCEDES-BENZ GT COUPE variants downloaded
# 2024 MERCEDES-BENZ EQE variants downloaded
# 2024 JAGUAR E-PACE variants downloaded
# 2024 SUBARU CROSSTREK WILDERNESS variants downloaded
# 2024 LEXUS RC 350 variants downloaded
# 2024 PORSCHE CAYENNE S E-HYBRID COUPÉ variants downloaded
# 2024 MERCEDES-BENZ GT 4-DOOR COUPE PHEV variants downloaded
# 2024 BMW X3 variants downloaded
# 2024 MERCEDES-BENZ MERCEDES-BENZ ESPRINTER (HO) variants downloaded
# 2024 CADILLAC CELESTIQ variants downloaded
# 2024 JEEP GRAND WAGONEER variants downloaded
# 2024 ROLLS-ROYCE GHOST variants downloaded
# 2024 TOYOTA COROLLA CROSS HYBRID variants downloaded
# 2024 AUDI S4 variants downloaded
# 2024 CHRYSLER VOYAGER variants downloaded
# 2024 CHRYSLER PACIFICA AWD variants downloaded
# 2024 PORSCHE 718 BOXSTER GTS 4.0 variants downloaded
# 2024 CHEVROLET SILVERADO EV variants downloaded
# 2025 LEXUS NX 250 variants downloaded
# 2024 BENTLEY BENTAYGA V8 variants downloaded
# 2024 AUDI A5 SPORTBACK variants downloaded
# 2024 LEXUS NX 350 variants downloaded
# 2024 INFINITI QX60 variants downloaded
# 2024 FORD F-150 (SUPER CAB) GAS variants downloaded
# 2024 BRIGHTDROP ZEVO 400 variants downloaded
# 2024 CHEVROLET COLORADO variants downloaded
# 2024 HYUNDAI PALISADE variants downloaded
# 2024 GENESIS ELECTRIFIED G80 variants downloaded
# 2024 CADILLAC CT4 variants downloaded
# 2024 FORD MAVERICK HEV variants downloaded
# 2025 HONDA CIVIC SEDAN variants downloaded
# 2024 AUDI RS Q8 variants downloaded
# 2024 MITSUBISHI OUTLANDER SPORT variants downloaded
# 2024 RIVIAN R1T variants downloaded
# 2024 VOLVO XC40 B5 variants downloaded
# 2024 BMW M3 SEDAN variants downloaded
# 2025 AUDI SQ7 variants downloaded
# 2024 NISSAN FRONTIER CREW CAB variants downloaded
# 2024 JEEP WRANGLER 4-DOOR RHD variants downloaded
# 2024 NISSAN ARIYA variants downloaded
# 2024 GENESIS GV60 variants downloaded
# 2024 HYUNDAI TUCSON HEV variants downloaded
# 2024 AUDI E-TRON GT variants downloaded
# 2024 NISSAN TITAN XD CREW CAB variants downloaded
# 2024 VOLVO S60 RECHARGE variants downloaded
# 2024 LEXUS LC 500 variants downloaded
# 2024 ROLLS-ROYCE CULLINAN variants downloaded
# 2024 PORSCHE CAYENNE E-HYBRID COUPÉ variants downloaded
# 2024 CADILLAC CT5 variants downloaded
# 2024 ACURA INTEGRA TYPE-S variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 2500 CREW VAN (LWB) variants downloaded
# 2024 PORSCHE CAYENNE COUPÉ variants downloaded
# 2024 MINI CLUBMAN variants downloaded
# 2024 CHEVROLET EXPRESS PASSENGER 3500- 12 PASSENGER variants downloaded
# 2024 LINCOLN NAUTILUS variants downloaded
# 2024 PORSCHE TAYCAN 4S CROSS TURISMO variants downloaded
# 2024 JAGUAR F-TYPE CONVERTIBLE variants downloaded
# 2024 LEXUS ES 250 variants downloaded
# 2024 HYUNDAI IONIQ 5 variants downloaded
# 2024 AUDI A3 variants downloaded
# 2024 CHEVROLET EQUINOX variants downloaded
# 2024 VOLVO XC40 RECHARGE variants downloaded
# 2025 KIA SORENTO HYBRID variants downloaded
# 2024 PORSCHE CAYENNE S E-HYBRID variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 4500 CREW VAN variants downloaded
# 2024 JEEP GRAND CHEROKEE variants downloaded
# 2024 FORD TRANSIT MEDIUM ROOF (8,10,12) PASS variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 2500 15 PASSENGER VAN variants downloaded
# 2024 PORSCHE 911 CARRERA 4S variants downloaded
# 2024 PORSCHE 911 CARRERA 4 variants downloaded
# 2024 HYUNDAI IONIQ 6 variants downloaded
# 2024 TOYOTA PRIUS PRIME variants downloaded
# 2024 FORD F-250 TREMOR (CREW CAB) variants downloaded
# 2024 AUDI Q4 SPORTBACK E-TRON variants downloaded
# 2024 PORSCHE 718 GT4 RS variants downloaded
# 2024 LEXUS ES 300H variants downloaded
# 2024 AUDI A5 COUPE variants downloaded
# 2024 DODGE HORNET variants downloaded
# 2024 HYUNDAI SONATA variants downloaded
# 2024 LAND ROVER DISCOVERY variants downloaded
# Attempt 1 timed out. Retrying...
# 2024 TESLA MODEL 3 variants downloaded
# 2024 AUDI Q8 SPORTBACK E-TRON variants downloaded
# 2024 TESLA MODEL X (ALL VARIANTS) variants downloaded
# 2024 PORSCHE 911 TARGA 4 variants downloaded
# 2025 LEXUS NX 350H variants downloaded
# 2024 FORD TRANSIT MEDIUM ROOF 15 PASS variants downloaded
# 2024 PORSCHE TAYCAN 4S variants downloaded
# 2024 MINI HARDTOP 4DR variants downloaded
# 2024 CHEVROLET TRAVERSE LIMITED variants downloaded
# 2024 LEXUS ES 350 variants downloaded
# 2024 FORD F-150 (SUPER CREW) GAS variants downloaded
# 2024 RAM PROMASTER BEV variants downloaded
# 2024 BMW 4 SERIES GRAN COUPE variants downloaded
# 2024 LEXUS RX 350H variants downloaded
# 2024 PORSCHE 718 CAYMAN STYLE EDITION variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 3500XD CREW VAN variants downloaded
# 2024 INFINITI QX50 variants downloaded
# 2024 LEXUS UX 250H variants downloaded
# 2024 LAND ROVER DEFENDER 130 variants downloaded
# 2024 LAND ROVER RANGE ROVER VELAR variants downloaded
# 2024 CADILLAC XT4 variants downloaded
# 2024 TOYOTA COROLLA HATCHBACK variants downloaded
# 2024 HYUNDAI SANTA FE HEV variants downloaded
# 2024 GMC CANYON AT4X AEV variants downloaded
# 2024 CHEVROLET SILVERADO 2500 variants downloaded
# 2024 HYUNDAI ELANTRA variants downloaded
# 2024 MERCEDES-BENZ S-CLASS variants downloaded
# 2024 AUDI S8 LWB variants downloaded
# 2024 MERCEDES-BENZ EQS variants downloaded
# 2024 SUBARU OUTBACK variants downloaded
# 2024 HYUNDAI SANTA FE variants downloaded
# 2024 BMW 8 SERIES GRAN COUPE variants downloaded
# 2024 BMW X4 M variants downloaded
# 2025 SUBARU LEGACY variants downloaded
# 2024 BENTLEY CONTINENTAL GT SPEED CONVERTIBLE variants downloaded
# 2024 KIA EV6 variants downloaded
# 2024 MITSUBISHI OUTLANDER PHEV variants downloaded
# 2024 CHEVROLET TAHOE variants downloaded
# 2024 VOLKSWAGEN JETTA variants downloaded
# 2024 PORSCHE 911 CARRERA GTS variants downloaded
# 2024 BENTLEY CONTINENTAL GT V8 CONVERTIBLE variants downloaded
# 2024 LAND ROVER RANGE ROVER SPORT variants downloaded
# 2024 BMW X5 M variants downloaded
# 2025 SUBARU FORESTER variants downloaded
# 2024 PORSCHE 911 CARRERA 4 GTS CABRIOLET variants downloaded
# 2024 PORSCHE 911 TURBO CABRIOLET variants downloaded
# 2024 NISSAN LEAF PLUS (60 kWH BATTERY) variants downloaded
# 2024 TOYOTA BZ4X variants downloaded
# 2024 PORSCHE 718 BOXSTER variants downloaded
# 2024 NISSAN ARMADA variants downloaded
# 2024 TOYOTA VENZA HYBRID variants downloaded
# 2024 LEXUS LX 600 variants downloaded
# 2024 VOLKSWAGEN ID.4 variants downloaded
# 2024 FORD TRANSIT HIGH ROOF (8,10,12) PASS variants downloaded
# 2024 PORSCHE 911 TURBO S CABRIOLET variants downloaded
# 2024 PORSCHE TAYCAN 4 CROSS TURISMO variants downloaded
# 2024 BMW X4 variants downloaded
# 2024 FORD MUSTANG MACH-E BEV variants downloaded
# 2024 VOLKSWAGEN GOLF R variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 2500 CARGO VAN (SWB) variants downloaded
# 2024 ALFA GIULIA variants downloaded
# 2024 FORD ESCAPE HEV variants downloaded
# 2024 VOLVO XC60 B5 variants downloaded
# 2024 MERCEDES-BENZ GLA variants downloaded
# 2024 RAM PROMASTER variants downloaded
# 2024 HONDA ACCORD SEDAN variants downloaded
# 2024 PORSCHE 911 SPORT CLASSIC variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 2500 CREW VAN (SWB) variants downloaded
# 2024 LAND ROVER DEFENDER 110 variants downloaded
# 2024 MAZDA CX-50 variants downloaded
# 2024 TOYOTA RAV4 variants downloaded
# 2024 LAND ROVER DISCOVERY SPORT variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 4500 CARGO VAN variants downloaded
# 2024 PORSCHE 911 CARRERA 4 GTS variants downloaded
# 2024 GMC SIERRA 1500 variants downloaded
# 2024 FORD ESCAPE variants downloaded
# 2024 ACURA MDX variants downloaded
# 2024 GMC CANYON variants downloaded
# 2024 PORSCHE CAYENNE S COUPÉ variants downloaded
# 2024 PORSCHE MACAN T variants downloaded
# 2024 BMW 8 SERIES CONVERTIBLE variants downloaded
# 2024 PORSCHE 911 50 YEARS PORSCHE DESIGN EDITION variants downloaded
# 2024 INFINITI Q50 variants downloaded
# 2024 TOYOTA CAMRY variants downloaded
# 2024 PORSCHE PANAMERA 4 variants downloaded
# 2024 BMW ALPINA XB7 variants downloaded
# 2024 AUDI RS 5 SPORTBACK variants downloaded
# 2024 JAGUAR F-TYPE COUPE variants downloaded
# 2024 AUDI S3 variants downloaded
# 2024 TOYOTA GRAND HIGHLANDER variants downloaded
# 2024 KIA CARNIVAL variants downloaded
# 2024 FORD F-150 (SUPER CREW) LIGHTNING BEV variants downloaded
# 2024 RAM RAM 1500 CREW CAB TRX variants downloaded
# 2024 TOYOTA HIGHLANDER variants downloaded
# 2024 SUBARU Solterra variants downloaded
# 2024 DODGE DURANGO variants downloaded
# 2024 MERCEDES-BENZ GT 4-DOOR COUPE variants downloaded
# 2024 AUDI RS 7 variants downloaded
# 2024 PORSCHE 911 S/T variants downloaded
# 2024 TOYOTA COROLLA variants downloaded
# 2024 PORSCHE 911 GT3 TOURING variants downloaded
# 2024 PORSCHE CAYENNE E-HYBRID variants downloaded
# 2024 CHEVROLET COLORADO ZR2 BISON variants downloaded
# 2024 CHEVROLET CAMARO LT1 WITH RECARO variants downloaded
# 2024 PORSCHE TAYCAN TURBO CROSS TURISMO variants downloaded
# 2024 AUDI A4 ALLROAD variants downloaded
# 2024 VOLVO C40 RECHARGE variants downloaded
# 2024 FORD EXPLORER HEV variants downloaded
# 2025 SUBARU OUTBACK WILDERNESS variants downloaded
# 2024 TOYOTA CAMRY HYBRID variants downloaded
# 2024 PORSCHE CAYENNE TURBO GT COUPÉ variants downloaded
# 2024 BMW 3 SERIES HYBRID SEDAN variants downloaded
# 2024 VOLVO V60 CROSS COUNTRY B5 variants downloaded
# 2024 TOYOTA SIENNA HYBRID variants downloaded
# 2025 ACURA MDX variants downloaded
# 2024 PORSCHE MACAN S variants downloaded
# 2024 PORSCHE 911 CARRERA 4 CABRIOLET variants downloaded
# 2024 TOYOTA HIGHLANDER HYBRID variants downloaded
# 2024 PORSCHE 911 CARRERA variants downloaded
# 2024 BENTLEY CONTINENTAL GT V8 variants downloaded
# 2024 ROLLS-ROYCE GHOST EWB variants downloaded
# 2024 MAZDA MX-5 variants downloaded
# 2024 CADILLAC ESCALADE variants downloaded
# 2024 CHRYSLER PACIFICA HYBRID variants downloaded
# 2024 PORSCHE 911 CARRERA 4S CABRIOLET variants downloaded
# 2024 LINCOLN CORSAIR PHEV variants downloaded
# 2024 VINFAST VF8 variants downloaded
# 2024 LEXUS LC 500 CONVERTIBLE variants downloaded
# 2024 POLESTAR POLESTAR 2 variants downloaded
# 2024 NISSAN LEAF (40 kWH BATTERY) variants downloaded
# 2024 LEXUS GX 550 variants downloaded
# 2024 MERCEDES-MAYBACH GLS variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 2500 CARGO VAN (LWB) variants downloaded
# 2024 HYUNDAI SONATA HEV variants downloaded
# 2024 FORD TRANSIT VAN variants downloaded
# 2024 FIAT 500E variants downloaded
# 2024 NISSAN KICKS variants downloaded
# 2024 AUDI Q7 variants downloaded
# 2024 PORSCHE CAYENNE variants downloaded
# 2024 CHEVROLET EXPRESS CARGO 3500 variants downloaded
# 2024 PORSCHE 718 GT4 variants downloaded
# 2025 LEXUS NX 350 variants downloaded
# 2024 NISSAN SENTRA variants downloaded
# 2024 LEXUS RX 500H variants downloaded
# Request failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024 BMW M8 CONVERTIBLE variants downloaded
# 2024 BENTLEY FLYING SPUR variants downloaded
# 2024 RAM RAM 2500 CREW CAB variants downloaded
# 2024 LINCOLN NAVIGATOR EL variants downloaded
# 2024 SUBARU LEGACY variants downloaded
# 2024 TOYOTA RAV4 PRIME variants downloaded
# 2024 TESLA MODEL Y (All Variants) variants downloaded
# 2024 VOLKSWAGEN TIGUAN variants downloaded
# 2024 GMC SIERRA 2500 variants downloaded
# 2024 AUDI Q5 PHEV variants downloaded
# 2024 CHEVROLET MALIBU variants downloaded
# 2024 LAND ROVER RANGE ROVER EVOQUE variants downloaded
# 2025 FORD EXPLORER HEV variants downloaded
# 2024 JEEP WRANGLER 4-DOOR variants downloaded
# 2024 PORSCHE MACAN 4 variants downloaded
# 2024 DODGE HORNET R/T EAWD variants downloaded
# 2024 JEEP WRANGLER 4-DOOR 392 variants downloaded
# 2024 KIA FORTE variants downloaded
# 2024 TOYOTA CROWN HYBRID variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 3500XD CARGO VAN variants downloaded
# 2024 AUDI RS E-TRON GT variants downloaded
# 2024 BENTLEY FLYING SPUR V8 variants downloaded
# 2024 RAM RAM 2500 MEGA CAB variants downloaded
# 2024 CHEVROLET EQUINOX EV variants downloaded
# 2024 GMC YUKON XL variants downloaded
# 2024 TOYOTA GRAND HIGHLANDER HYBRID variants downloaded
# 2024 BMW M2 COUPE variants downloaded
# 2024 AUDI SQ5 SPORTBACK variants downloaded
# 2024 GMC YUKON variants downloaded
# 2024 BUICK ENCLAVE variants downloaded
# 2024 CHEVROLET BLAZER variants downloaded
# 2024 MINI HARDTOP 2DR variants downloaded
# 2024 MITSUBISHI MIRAGE variants downloaded
# 2025 AUDI Q7 variants downloaded
# 2024 SUBARU FORESTER variants downloaded
# 2024 PORSCHE CAYENNE TURBO E-HYBRID variants downloaded
# 2024 KIA SPORTAGE PLUG-IN HYBRID variants downloaded
# 2024 PORSCHE 718 CAYMAN variants downloaded
# 2024 GMC ACADIA variants downloaded
# 2024 CHEVROLET EXPRESS CARGO 2500 variants downloaded
# 2024 MITSUBISHI ECLIPSE CROSS variants downloaded
# 2024 PORSCHE 911 TARGA 4S variants downloaded
# 2024 MERCEDES-BENZ C-CLASS variants downloaded
# 2024 FORD F-150 (REGULAR CAB) GAS variants downloaded
# 2024 PORSCHE 911 GT3 variants downloaded
# 2024 AUDI S6 SEDAN variants downloaded
# 2024 LEXUS RC F variants downloaded
# 2024 LEXUS LC 500H variants downloaded
# 2024 LINCOLN NAUTILUS - FHEV variants downloaded
# 2024 LAND ROVER RANGE ROVER LWB variants downloaded
# 2024 SUBARU CROSSTREK variants downloaded
# 2024 CADILLAC ESCALADE ESV variants downloaded
# 2024 BRIGHTDROP ZEVO 600 variants downloaded
# 2024 MERCEDES-BENZ GLE COUPE variants downloaded
# 2024 HYUNDAI ELANTRA HEV variants downloaded
# 2024 PORSCHE 911 TARGA 4 GTS variants downloaded
# 2024 FORD TRANSIT LOW ROOF (8,10,12) PASS variants downloaded
# 2024 CHRYSLER PACIFICA variants downloaded
# 2024 BMW 2 SERIES COUPE variants downloaded
# 2024 VOLKSWAGEN ATLAS CROSS SPORT variants downloaded
# 2024 JAGUAR I-PACE variants downloaded
# 2024 PORSCHE 718 BOXSTER STYLE EDITION variants downloaded
# 2024 LEXUS IS 300 variants downloaded
# 2024 ACURA RDX variants downloaded
# 2024 LEXUS RZ 450E variants downloaded
# 2024 SUBARU OUTBACK WILDERNESS variants downloaded
# 2024 MINI COUNTRYMAN variants downloaded
# 2024 BUICK ENCORE GX variants downloaded
# 2024 ACURA ZDX variants downloaded
# 2024 CADILLAC CT5 WITH V6 variants downloaded
# 2024 LINCOLN AVIATOR variants downloaded
# 2024 CHEVROLET CAMARO WITHOUT RECARO variants downloaded
# 2024 TOYOTA RAV4 HYBRID variants downloaded
# 2024 PORSCHE 911 DAKAR variants downloaded
# 2024 KIA NIRO PLUG-IN HYBRID variants downloaded
# 2024 JEEP WAGONEER L variants downloaded
# 2024 GMC HUMMER EV variants downloaded
# 2024 PORSCHE 911 TURBO variants downloaded
# 2024 HYUNDAI ELANTRA N variants downloaded
# 2024 LEXUS RX 350 variants downloaded
# 2024 PORSCHE TAYCAN GTS variants downloaded
# 2024 PORSCHE 911 CARRERA GTS CABRIOLET variants downloaded
# 2024 TOYOTA TUNDRA variants downloaded
# 2024 PORSCHE 718 CAYMAN T variants downloaded
# 2024 AUDI SQ5 variants downloaded
# 2024 VOLVO V60 RECHARGE POLESTAR ENGINEERED variants downloaded
# 2024 GENESIS GV80 variants downloaded
# 2024 PORSCHE CAYENNE TURBO E-HYBRID COUPÉ variants downloaded
# 2024 CHEVROLET TRAILBLAZER variants downloaded
# 2024 FORD ESCAPE PHEV variants downloaded
# 2024 FORD BRONCO SPORT variants downloaded
# 2024 BMW 2 SERIES GRAN COUPE variants downloaded
# 2024 RAM RAM 2500 REGULAR CAB variants downloaded
# 2025 RAM RAM 1500 CREW CAB TRX variants downloaded
# 2024 AUDI RS 5 COUPE variants downloaded
# 2024 BMW 7 SERIES SEDAN variants downloaded
# 2024 DODGE DURANGO PURSUIT variants downloaded
# 2024 FORD F-350 (REGULAR CAB) variants downloaded
# 2024 VOLVO XC60 RECHARGE variants downloaded
# 2024 FORD F-350 (CREW CAB) variants downloaded
# 2024 KIA TELLURIDE variants downloaded
# 2024 FORD TRANSIT HIGH ROOF 15 PASS variants downloaded
# 2024 PORSCHE MACAN variants downloaded
# 2024 MERCEDES-MAYBACH EQS SUV variants downloaded
# 2024 TOYOTA GR86 variants downloaded
# Attempt 1 timed out. Retrying...
# 2024 AUDI S7 variants downloaded
# 2024 PORSCHE 911 CARRERA S CABRIOLET variants downloaded
# 2024 NISSAN Z variants downloaded
# 2024 HONDA CIVIC HATCHBACK variants downloaded
# 2024 MERCEDES-BENZ E-CLASS variants downloaded
# 2024 MERCEDES-BENZ C-CLASS PHEV variants downloaded
# 2024 CHEVROLET EXPRESS PASSENGER 3500- 15 PASSENGER variants downloaded
# 2024 NISSAN GTR variants downloaded
# 2024 HONDA ACCORD HYBRID variants downloaded
# 2024 MERCEDES-BENZ SL variants downloaded
# 2024 HONDA CIVIC HATCHBACK TYPE R variants downloaded
# 2024 RIVIAN EDV 700 variants downloaded
# 2024 NISSAN TITAN CREW CAB variants downloaded
# 2024 MERCEDES-BENZ CLE variants downloaded
# 2024 PORSCHE 911 CARRERA T variants downloaded
# 2024 AUDI SQ8 SPORTBACK E-TRON variants downloaded
# 2025 SUBARU OUTBACK variants downloaded
# 2024 GMC SAVANA PASSENGER 3500- 12 PASSENGER variants downloaded
# 2024 HONDA CR-V variants downloaded
# 2024 BMW X6 variants downloaded
# 2024 AUDI S5 CABRIOLET variants downloaded
# 2024 MERCEDES-BENZ E-CLASS WAGON variants downloaded
# 2024 MAZDA MAZDA3 variants downloaded
# 2024 TOYOTA TUNDRA HYBRID variants downloaded
# 2024 AUDI S5 COUPE variants downloaded
# 2025 RAM RAM 1500 QUAD CAB variants downloaded
# 2024 FORD TRANSIT LOW ROOF 15 PASS variants downloaded
# 2024 LEXUS LS 500H variants downloaded
# 2024 CADILLAC CT5-V BLACKWING variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 3500 CREW VAN variants downloaded
# 2024 ACURA INTEGRA variants downloaded
# 2024 PORSCHE 911 CARRERA S variants downloaded
# 2024 AUDI RS 6 AVANT variants downloaded
# 2024 GENESIS GV70 variants downloaded
# 2024 KIA SORENTO variants downloaded
# 2024 LEXUS LS 500 variants downloaded
# 2024 BMW 4 SERIES CONVERTIBLE variants downloaded
# 2024 PORSCHE TAYCAN TURBO S CROSS TURISMO variants downloaded
# 2024 AUDI SQ8 variants downloaded
# 2024 TOYOTA SEQUOIA HYBRID variants downloaded
# 2024 LEXUS RZ 300E variants downloaded
# 2025 HONDA CIVIC SEDAN HYBRID variants downloaded
# 2024 MERCEDES-BENZ G-CLASS variants downloaded
# 2024 AUDI A8 LWB variants downloaded
# 2024 JEEP GRAND CHEROKEE 4XE variants downloaded
# 2024 VOLVO S90 RECHARGE variants downloaded
# 2024 VOLVO V90 CROSS COUNTRY B6 variants downloaded
# 2024 BMW X7 variants downloaded
# 2025 RAM RAM 1500 CREW CAB variants downloaded
# 2024 HYUNDAI KONA ELECTRIC variants downloaded
# 2024 TOYOTA COROLLA CROSS variants downloaded
# 2024 PORSCHE 718 SPYDER variants downloaded
# 2024 BENTLEY CONTINENTAL GT CONVERTIBLE variants downloaded
# 2024 LEXUS IS 350 variants downloaded
# 2024 GENESIS G90 variants downloaded
# 2025 HONDA PILOT variants downloaded
# 2024 TESLA MODEL S (ALL VARIANTS) variants downloaded
# 2024 TOYOTA GR COROLLA variants downloaded
# 2024 JEEP WRANGLER 4-DOOR 4XE variants downloaded
# 2024 AUDI A5 CABRIOLET variants downloaded
# 2024 MERCEDES-BENZ GLC COUPE variants downloaded
# 2024 CHEVROLET SUBURBAN variants downloaded
# 2024 BMW IX variants downloaded
# 2024 MERCEDES-BENZ GLE variants downloaded
# 2024 GMC SAVANA CARGO 2500 variants downloaded
# 2024 GENESIS ELECTRIFIED GV70 variants downloaded
# 2024 PORSCHE MACAN TURBO variants downloaded
# 2024 NISSAN VERSA variants downloaded
# 2024 MAZDA CX-30 variants downloaded
# 2024 SUBARU BRZ variants downloaded
# 2024 MERCEDES-BENZ CLE CABRIOLET variants downloaded
# 2024 KIA SOUL variants downloaded
# 2024 MERCEDES-BENZ SL PHEV variants downloaded
# 2024 MERCEDES-BENZ GLE PHEV variants downloaded
# 2024 SUBARU ASCENT variants downloaded
# 2024 GMC SAVANA CARGO 3500 variants downloaded
# 2024 LEXUS TX 500H variants downloaded
# 2025 HONDA HR-V variants downloaded
# 2024 LUCID AIR variants downloaded
# 2024 VOLVO S90 B6 variants downloaded
# 2024 KIA NIRO variants downloaded
# 2024 PORSCHE 911 TURBO S variants downloaded
# 2024 AUDI RS 3 variants downloaded
# 2024 MERCEDES-BENZ GLB variants downloaded
# 2024 AUDI Q4 E-TRON variants downloaded
# 2024 PORSCHE 718 SPYDER RS variants downloaded
# 2024 LEXUS RC 300 variants downloaded
# 2024 LEXUS TX 350 variants downloaded
# 2024 BENTLEY BENTAYGA HYBRID variants downloaded
# 2024 MERCEDES-BENZ EQS SUV variants downloaded
# 2024 LEXUS NX 350H variants downloaded
# 2024 TOYOTA MIRAI variants downloaded
# 2024 BMW X3 M variants downloaded
# 2024 ALFA STELVIO variants downloaded
# 2024 NISSAN PATHFINDER variants downloaded
# 2024 MITSUBISHI OUTLANDER variants downloaded
# 2024 LAND ROVER DEFENDER 90 variants downloaded
# 2024 JAGUAR F-PACE variants downloaded
# 2024 GENESIS G70 variants downloaded
# 2025 FORD EXPLORER variants downloaded
# 2024 BENTLEY CONTINENTAL GT SPEED variants downloaded
# 2024 HONDA PILOT variants downloaded
# 2025 ACURA INTEGRA variants downloaded
# 2024 CHEVROLET CORVETTE E-RAY variants downloaded
# 2024 CHEVROLET SILVERADO 1500 variants downloaded
# 2024 CADILLAC CT4-V BLACKWING variants downloaded
# 2024 JEEP GLADIATOR variants downloaded
# 2024 VOLKSWAGEN GOLF GTI variants downloaded
# 2024 RIVIAN R1S variants downloaded
# 2024 FORD RANGER (SUPER CREW) variants downloaded
# 2024 PORSCHE 911 GT3 RS variants downloaded
# 2024 AUDI A6 SEDAN variants downloaded
# 2024 JAGUAR XF variants downloaded
# 2024 HONDA ODYSSEY variants downloaded
# 2024 TOYOTA 4RUNNER variants downloaded
# 2024 AUDI Q5 SPORTBACK variants downloaded
# 2024 RIVIAN EDV 500 variants downloaded
# 2024 FORD F-150 (SUPER CREW) HEV variants downloaded
# 2024 FORD F-250 (SUPER CAB) variants downloaded
# 2024 BMW XM variants downloaded
# 2024 CHEVROLET CAMARO SS WITH RECARO variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 2500 PASSENGER VAN variants downloaded
# 2024 CHEVROLET BLAZER EV variants downloaded
# 2024 HONDA CR-V HYBRID variants downloaded
# 2024 FORD F-250 (REGULAR CAB) variants downloaded
# 2024 CHEVROLET CAMARO SS WITHOUT RECARO variants downloaded
# 2024 AUDI Q5 variants downloaded
# 2024 BMW 3 SERIES SEDAN variants downloaded
# 2024 TOYOTA TACOMA variants downloaded
# 2024 RAM RAM 1500 CREW CAB variants downloaded
# 2024 CHEVROLET EXPRESS PASSENGER 2500 variants downloaded
# 2024 MINI CONVERTIBLE variants downloaded
# 2024 KIA SPORTAGE variants downloaded
# 2024 FORD MAVERICK variants downloaded
# 2024 GMC TERRAIN variants downloaded
# 2024 LEXUS IS 500 variants downloaded
# 2024 CHEVROLET CAMARO ZL1 WITH RECARO variants downloaded
# 2024 NISSAN FRONTIER KING CAB variants downloaded
# 2024 HYUNDAI NEXO variants downloaded
# 2024 CHEVROLET TRAVERSE variants downloaded
# 2024 MERCEDES-BENZ GLS variants downloaded
# 2024 HYUNDAI VENUE variants downloaded
# 2024 NISSAN MURANO variants downloaded
# 2024 KIA SPORTAGE HYBRID variants downloaded
# 2024 BMW Z4 variants downloaded
# 2024 MINI COOPER SE variants downloaded
# 2024 CADILLAC XT6 variants downloaded
# 2024 MERCEDES-BENZ CLA variants downloaded
# 2024 VOLKSWAGEN JETTA GLI variants downloaded
# 2024 AUDI Q3 variants downloaded
# 2024 AUDI A4 variants downloaded
# 2024 SUBARU WRX variants downloaded
# 2024 LEXUS NX 250 variants downloaded
# 2024 HONDA HR-V variants downloaded
# 2024 BUICK ENVISION variants downloaded
# 2024 PORSCHE PANAMERA variants downloaded
# 2024 BMW M8 COUPE variants downloaded
# 2024 LAND ROVER RANGE ROVER variants downloaded
# 2024 MERCEDES-MAYBACH S-CLASS variants downloaded
# 2024 HONDA RIDGELINE variants downloaded
# 2024 HYUNDAI TUCSON PHEV variants downloaded
# 2024 SUBARU FORESTER WILDERNESS variants downloaded
# 2024 HYUNDAI TUCSON variants downloaded
# 2025 LEXUS UX 300H variants downloaded
# 2024 TESLA CYBERTRUCK (ALL VARIANTS) variants downloaded
# 2024 HYUNDAI SANTA CRUZ variants downloaded
# 2025 LINCOLN AVIATOR variants downloaded
# 2024 KIA EV9 variants downloaded
# 2024 INFINITI QX80 variants downloaded
# 2024 CHEVROLET CAMARO LT1 WITHOUT RECARO variants downloaded
# 2024 TOYOTA PRIUS variants downloaded
# 2024 MERCEDES-BENZ EQE SUV variants downloaded
# 2024 AUDI A6 ALLROAD variants downloaded
# 2024 ROLLS-ROYCE PHANTOM EWB variants downloaded
# 2024 FORD EXPEDITION EL variants downloaded
# 2024 RAM RAM 1500 QUAD CAB variants downloaded
# 2024 PORSCHE 718 BOXSTER T variants downloaded
# 2024 BMW I7 SEDAN variants downloaded
# 2024 HYUNDAI KONA variants downloaded
# 2024 PORSCHE 718 BOXSTER S variants downloaded
# 2024 KIA SORENTO PLUG-IN HYBRID variants downloaded
# 2024 CHEVROLET CAMARO WITH RECARO variants downloaded
# 2024 GMC SAVANA PASSENGER 2500 variants downloaded
# 2024 BMW X1 variants downloaded
# 2024 VOLVO XC90 B5 variants downloaded
# 2024 CADILLAC CT4-V variants downloaded
# 2024 LEXUS NX 450H+ variants downloaded
# 2024 FORD MUSTANG variants downloaded
# 2024 MERCEDES-BENZ SPRINTER 2500 CARGO VAN variants downloaded
# 2024 ROLLS-ROYCE PHANTOM variants downloaded
# 2024 HONDA CIVIC SEDAN SI variants downloaded
# 2024 KIA NIRO EV variants downloaded
# 2024 PORSCHE TAYCAN TURBO S variants downloaded
# 2024 FORD F-350 (SUPER CAB) variants downloaded
# 2024 PORSCHE TAYCAN variants downloaded
# 2024 PORSCHE MACAN GTS variants downloaded
# 2024 BMW M4 COUPE variants downloaded
# 2024 NISSAN TITAN KING CAB variants downloaded
# 2024 BMW X5 HYBRID variants downloaded
# 2024 FORD EXPEDITION variants downloaded
# 2024 VOLKSWAGEN TAOS variants downloaded
# 2024 KIA K5 variants downloaded
# 2024 AUDI S5 SPORTBACK variants downloaded
# 2024 HONDA CIVIC SEDAN variants downloaded
# 2024 BMW 8 SERIES COUPE variants downloaded
# 2024 VOLKSWAGEN ATLAS variants downloaded
# 2024 PORSCHE CAYENNE S variants downloaded
# 2024 HONDA PROLOGUE EV variants downloaded
# 2024 MERCEDES-BENZ GLC variants downloaded
# 2024 DODGE DURANGO SRT variants downloaded
# 2024 GENESIS G80 variants downloaded
# 2024 FORD EDGE variants downloaded
# 2024 LINCOLN NAVIGATOR variants downloaded
# 2024 AUDI A7 variants downloaded
# 2024 SUBARU IMPREZA variants downloaded
# 2024 AUDI Q8 E-TRON variants downloaded
# 2024 JEEP COMPASS variants downloaded
# 2024 ALFA TONALE EAWD variants downloaded
# 2024 PORSCHE TAYCAN TURBO variants downloaded
# 2024 BENTLEY BENTAYGA V8 EWB variants downloaded
# 2024 ALFA GIULIA QUADRIFOGLIO variants downloaded
# 2024 PORSCHE 911 CARRERA CABRIOLET variants downloaded
# 2024 MERCEDES-BENZ EQB variants downloaded
# 2024 JEEP WRANGLER 2-DOOR variants downloaded
# 2024 ACURA TLX variants downloaded
# 2024 VOLVO XC90 RECHARGE variants downloaded
# 2025 HONDA CR-V variants downloaded
# 2024 ALFA STELVIO QUADRIFOGLIO variants downloaded
# 2024 VOLVO XC90 B6 variants downloaded
# 2025 HONDA CR-V HYBRID variants downloaded
# 2024 FORD BRONCO variants downloaded
# 2024 VOLVO S60 B5 variants downloaded
# 2024 KIA SORENTO HYBRID variants downloaded
# 2024 TOYOTA COROLLA HYBRID variants downloaded
# 2024 MAZDA CX-5 variants downloaded
# 2024 BMW X5 variants downloaded
# 2024 RIVIAN RCV-DELIVERY 500 variants downloaded
# Attempt 1 timed out. Retrying...
# 2024 MAZDA CX-90-PHEV variants downloaded
# 2024 AUDI Q8 variants downloaded
# 2024 BMW 4 SERIES COUPE variants downloaded
# 2024 LINCOLN CORSAIR variants downloaded
# 2024 CADILLAC LYRIQ variants downloaded
# 2024 MERCEDES-BENZ S-CLASS PHEV variants downloaded
# 2024 LEXUS TX 550H+ variants downloaded
# 2024 INFINITI QX55 variants downloaded
# 2024 PORSCHE 718 CAYMAN S variants downloaded
# Duplicates removed from ratings_models_variants

# %%
# Get makes for ratings year
def get_rating(vehicleid,retries=3, timeout=30):
    url = f'https://api.nhtsa.gov/SafetyRatings/VehicleId/{vehicleid}'
    attempt = 0
    while attempt < retries:
            try:
                # Make the GET request to the NHTSA API with a timeout
                response = requests.get(url, timeout=timeout)
                
                # Check if the request was successful
                if response.status_code == 200:
                    # Return the JSON response
                    return response.json().get('Results', [])
                elif response.status_code == 400:
                    return None
                else:
                    # Return an error message
                    return None
            except Timeout:
                # Handle timeout exception
                attempt += 1
                print(f"Attempt {attempt} timed out. Retrying...")
                time.sleep(5)  # wait before retrying
            except RequestException as e:
                attempt += 1
                # Handle other request exceptions
                print(f"Request failed: {e}")
                time.sleep(5)
            except Exception as e:
                attempt += 1
                print(f"Request failed: {e}")
                time.sleep(5)

    # If all attempts fail, return None
    print("All attempts to contact the API have failed.")
    return None

if 'ratings_download_tracker' not in pg_tables():
    query = """
    create table ratings_download_tracker as 
    select
        *,
        current_timestamp - interval '1000 years' as ratings_last_updated,
        false as fetched_ratings,
        false as rated
    from ratings_models_variants            
    """
    pg_execute(query)

# Update complaint download tracker
pg_execute("""
INSERT INTO ratings_download_tracker
select distinct on ("VehicleId")
	*,
	current_timestamp - interval '1000 years' as ratings_last_updated,
    false as feched_ratings,
    false as rated
from ratings_models_variants
where ("VehicleId") not in (select "VehicleId" from ratings_download_tracker)
""")
# Out:
# 'done'

# %%
ratings_download_tracker = pg_query("""
select 
    *
from ratings_download_tracker
where fetched_ratings = false
union all
(select
    *
from ratings_download_tracker
where fetched_ratings = true
and rated = false
and ratings_last_updated < current_date - interval '14 days'
and "ModelYear"::int = extract(year from current_date)
limit 50
)
union all 
(select
    *
from ratings_download_tracker
where fetched_ratings = true
and rated = false
and "ModelYear"::int > extract(year from current_date)
)
""")

db = pg_connect()
t = pg_query("select current_timestamp")['current_timestamp'][0]
for _,row in ratings_download_tracker.iterrows():
    ratings = get_rating(row['VehicleId'])
    ratings_df = pd.DataFrame(ratings)[['OverallRating', 'OverallFrontCrashRating',
       'FrontCrashDriversideRating', 'FrontCrashPassengersideRating',
       'OverallSideCrashRating', 'SideCrashDriversideRating',
       'SideCrashPassengersideRating',
       'combinedSideBarrierAndPoleRating-Front',
       'combinedSideBarrierAndPoleRating-Rear', 'sideBarrierRating-Overall',
       'RolloverRating', 'RolloverRating2', 'RolloverPossibility',
       'RolloverPossibility2', 'dynamicTipResult', 'SidePoleCrashRating',
       'NHTSAElectronicStabilityControl', 'NHTSAForwardCollisionWarning',
       'NHTSALaneDepartureWarning', 'ModelYear', 'Make', 'Model',
       'VehicleDescription', 'VehicleId']]
    ratings_df['rating_updated_on'] = t
    ratings_df.to_sql('ratings',db,index=False,if_exists='append')
    if ratings_df['OverallRating'].iloc[0] == 'Not Rated':
        rated = False
    else:
        rated = True

    with db.connect() as connection:
        query = text("""
        update ratings_download_tracker
        set 
            ratings_last_updated = :t, 
            fetched_ratings = true, 
            rated = :r
        where  "VehicleId" = :a
        """)
        connection.execute(query,{'a':row['VehicleId'],'r':rated,'t':t})
        connection.commit()
    print(f'{row['VehicleDescription']} ratings fetched.')
    time.sleep(1)
db.dispose()
pg_execute("drop table if exists ratings_backup")
pg_execute("""
create table ratings_backup as
select distinct on ("VehicleId")
*
from ratings
order by "VehicleId", rating_updated_on desc
""")
pg_execute("delete from ratings")
pg_execute("""
insert into ratings
select * from ratings_backup
""")
pg_execute("drop table ratings_backup")
print("ratings updated")
# Out:
# 2025 Honda CR-V SUV FWD ratings fetched.
# 2025 Lexus NX 350h SUV AWD ratings fetched.
# 2025 Lexus NX 250 SUV FWD ratings fetched.
# 2025 Ford Explorer SUV RWD ratings fetched.
# 2025 Ram Ram 1500 Crew Cab PU/CC RWD ratings fetched.
# 2025 Subaru Outback Wilderness SW AWD ratings fetched.
# 2025 Ford Explorer HEV SUV 4WD ratings fetched.
# 2025 Lexus NX 350 SUV AWD ratings fetched.
# 2025 Ram Ram 1500 Crew Cab PU/CC 4WD ratings fetched.
# 2025 Ram Ram 1500 Quad Cab PU/EC 4WD ratings fetched.
# 2025 Acura MDX SUV AWD ratings fetched.
# 2025 Ford Explorer HEV SUV RWD ratings fetched.
# 2025 Ram Ram 1500 Crew Cab TRX PU/CC 4WD ratings fetched.
# 2025 Ford Explorer SUV 4WD ratings fetched.
# 2025 Audi SQ7 SUV AWD ratings fetched.
# 2025 Lincoln Aviator SUV 4WD ratings fetched.
# 2025 Honda HR-V SUV AWD ratings fetched.
# 2025 Lexus NX 250 SUV AWD ratings fetched.
# 2025 Subaru Forester SUV AWD ratings fetched.
# 2025 Kia Sorento Hybrid SUV AWD ratings fetched.
# 2025 Lincoln Aviator SUV RWD ratings fetched.
# 2025 Ram Ram 1500 Quad Cab PU/EC RWD ratings fetched.
# 2025 Honda CR-V HYBRID SUV FWD ratings fetched.
# 2025 Kia Sorento Hybrid SUV FWD ratings fetched.
# ratings updated
