# %%
import pandas as pd
import requests
import time
from datetime import date, datetime

from config import *

########################################
# Main function to download complaints
########################################
# Function to get complaints from NHTSA API
import requests
from requests.exceptions import Timeout, RequestException
import time

# Function to get complaints from NHTSA API
def get_complaints(make, model, model_year, retries=3, timeout=30):
    # Construct the API URL
    url = f"https://api.nhtsa.gov/complaints/complaintsByVehicle?make={make}&model={model}&modelYear={model_year}"

    attempt = 0

    while attempt < retries:
        try:
            # Make the GET request to the NHTSA API with a timeout
            response = requests.get(url, timeout=timeout)
            
            # Check if the request was successful
            if response.status_code == 200:
                # Return the JSON response
                return response.json().get('results', [])
            elif response.status_code == 400:
                return None
            else:
                # Return an error message
                return None
        except Timeout:
            # Handle timeout exception
            attempt += 1
            print(f"Attempt {attempt} timed out. Retrying...")
            time.sleep(5)  # wait before retrying
        except RequestException as e:
            attempt += 1
            # Handle other request exceptions
            print(f"Request failed: {e}")
            time.sleep(5)
        except Exception as e:
            attempt += 1
            print(f"Request failed: {e}")
            time.sleep(5)

    # If all attempts fail, return None
    print("All attempts to contact the API have failed.")
    return None


########################################
# Update Model Years
########################################
# Function to get all Model Years
# Function to get all Model Years
def get_complaints_model_years(retries=3, timeout=30):
    url = "https://api.nhtsa.gov/products/vehicle/modelYears?issueType=c"
    
    attempt = 0

    while attempt < retries:
        try:
            # Make the GET request to the NHTSA API with a timeout
            response = requests.get(url, timeout=timeout)
            
            # Check if the request was successful
            if response.status_code == 200:
                return pd.DataFrame(response.json().get('results', []))
            else:
                return f"Error: {response.status_code}"
        
        except Timeout:
            # Handle timeout exception
            attempt += 1
            print(f"Attempt {attempt} timed out. Retrying...")
            time.sleep(5)  # wait before retrying
        except RequestException as e:
            attempt += 1
            # Handle other request exceptions
            print(f"Request failed: {e}")
            time.sleep(5)
        except Exception as e:
            attempt += 1
            print(f"Request failed: {e}")
            time.sleep(5)

    # If all attempts fail, return an error message
    print("All attempts to contact the API have failed.")
    return "Error: All attempts to contact the API have failed."

# Fetch model years
complaints_model_years = get_complaints_model_years()

# Save model years to database
db = pg_connect()
complaints_model_years.to_sql('complaints_model_years',db,index=False,if_exists='replace')


########################################
# Update Makes
########################################
# Function to get all Makes for the Model Year
# Function to get makes for a specific year
def get_complaints_makes_for_years(year, retries=3, timeout=30):
    url = f"https://api.nhtsa.gov/products/vehicle/makes?modelYear={year}&issueType=c"
    
    attempt = 0

    while attempt < retries:
        try:
            # Make the GET request to the NHTSA API with a timeout
            response = requests.get(url, timeout=timeout)
            
            # Check if the request was successful
            if response.status_code == 200:
                return pd.DataFrame(response.json().get('results', []))
            else:
                return f"Error: {response.status_code}"
        
        except Timeout:
            # Handle timeout exception
            attempt += 1
            print(f"Attempt {attempt} timed out. Retrying...")
            time.sleep(5)  # wait before retrying
        except RequestException as e:
            attempt += 1
            # Handle other request exceptions
            print(f"Request failed: {e}")
            time.sleep(5)
        except Exception as e:
            attempt += 1
            print(f"Request failed: {e}")
            time.sleep(5)

    # If all attempts fail, return an error message
    print("All attempts to contact the API have failed.")
    return "Error: All attempts to contact the API have failed."


for year in complaints_model_years[complaints_model_years['modelYear'].astype(int)>=2016]['modelYear']:
    print(f'Downloading makes for year {year}')
    complaints_makes_for_years = get_complaints_makes_for_years(year)
    complaints_makes_for_years
    complaints_makes_for_years.to_sql('complaints_makes_for_years',db,index=False,if_exists='append')
db.dispose()
# Remove duplicate rows from the table
pg_clean_table('complaints_makes_for_years')
# Out:
# Configuration loaded successfully.
# Downloading makes for year 2016
# Downloading makes for year 2017
# Downloading makes for year 2018
# Downloading makes for year 2019
# Downloading makes for year 2020
# Downloading makes for year 2021
# Downloading makes for year 2022
# Downloading makes for year 2023
# Downloading makes for year 2024
# Downloading makes for year 2025
# Downloading makes for year 9999
# Duplicates removed from complaints_makes_for_years

# %%
# Create table to track model updates
if 'complaints_model_download_tracker' not in pg_tables():
    query = """
create table complaints_model_download_tracker as
select
	*,
	CURRENT_TIMESTAMP - interval '1000 years' as models_last_updated,
    0 as models_downloaded
from complaints_makes_for_years
"""
    pg_execute(query)
    print("complaints_model_download_tracker table created")

# Update model download tracker
pg_execute("""
INSERT INTO complaints_model_download_tracker
select distinct on ("modelYear",make)
	"modelYear",
	make,
	CURRENT_TIMESTAMP - interval '1000 years' as models_last_updated,
    0 as models_downloaded
from complaints_makes_for_years
where ("modelYear","make") not in (select "modelYear",make from complaints_model_download_tracker)
""")
print("complaints_model_download_tracker updated")


########################################
# Update Models
########################################
# Function to get all Models for the Make and Model Year
def get_complaints_models(make, year, retries=3, timeout=30):
    url = f"https://api.nhtsa.gov/products/vehicle/models?modelYear={year}&make={make}&issueType=c"
    
    attempt = 0

    while attempt < retries:
        try:
            response = requests.get(url, timeout=timeout)
            
            if response.status_code == 200:
                return response.json().get('results', [])
            else:
                return f"Error: {response.status_code}"
        
        except Timeout:
            # Handle timeout exception
            attempt += 1
            print(f"Attempt {attempt} timed out. Retrying...")
            time.sleep(5)  # wait before retrying
        except RequestException as e:
            attempt += 1
            # Handle other request exceptions
            print(f"Request failed: {e}")
            time.sleep(5)
        except Exception as e:
            attempt += 1
            print(f"Request failed: {e}")
            time.sleep(5)

    print("All attempts to contact the API have failed.")
    return "Error: All attempts to contact the API have failed."

complaints_makes_for_years = pg_query("""
select distinct 
	"modelYear",
	make,
    models_last_updated,
    models_downloaded
from complaints_model_download_tracker 
where "modelYear"::int >= extract(year from current_date) 
and models_last_updated < CURRENT_DATE - INTERVAL '7 days'
union all
select
	"modelYear",
	make,
    models_last_updated,
    models_downloaded
from (
	SELECT DISTINCT
		*,
		random()
	FROM complaints_model_download_tracker
	WHERE "modelYear"::int < EXTRACT(YEAR FROM CURRENT_DATE)
	  AND "modelYear"::int >= EXTRACT(YEAR FROM CURRENT_DATE) - 5
	  AND models_last_updated < CURRENT_DATE - INTERVAL '15 days'
      AND models_downloaded = 0
	order by random() desc
	limit 500
) tbl      
""")

all_models = []
if len(complaints_makes_for_years) > 0:
    db = pg_connect()
    for _,row in complaints_makes_for_years.iterrows():
        print(f"Downloading {row['make']} {row['modelYear']} models")
        # Download models
        try:
            download = get_complaints_models(row['make'],str(row['modelYear']))
        except Exception as e:
            print("Download failed. Will try again next update.")
        # add to list
        print(download)
        payload = pd.DataFrame(download)
        if len(payload) > 0:
            payload.to_sql('complaints_models',db,index=False, if_exists='append')
        # Update complaints_model_download_tracker
        with db.connect() as connection:
            query = text('''
                update complaints_model_download_tracker
                set models_last_updated = current_timestamp,
                    models_downloaded = :x
                where "modelYear" = :y and make = :z
                ''')
            connection.execute(query,{'x':len(payload),'y':str(row['modelYear']),'z':row['make']})
            connection.commit()
        # Done.    
        print(f"{row['modelYear']} {row['make']} models updated: {payload.shape[0]} new models")
        time.sleep(2)
    db.dispose()
    # Clean database
    pg_clean_table('complaints_models')
    print(f"complaints_models table cleaned")

########################################
# Update Complaints
########################################
# Create table to track complaint updates
if 'complaints_download_tracker' not in pg_tables():
    query = """
create table complaints_download_tracker as
select
	*,
	CURRENT_TIMESTAMP - interval '1000 years' as complaints_last_updated,
    0 as total_complaints
from complaints_models
"""
    pg_execute(query)
    print("complaints_download_tracker table created")

# Update complaint download tracker
pg_execute("""
INSERT INTO complaints_download_tracker
select distinct on ("modelYear","make","model")
	"modelYear",
	make,
    "model",
	CURRENT_TIMESTAMP - interval '1000 years' as complaints_last_updated,
    0 as total_complaints
from complaints_models
where ("modelYear","make","model") not in (select "modelYear","make","model" from complaints_download_tracker)
""")

print("complaints_download_tracker updated")

def update_complaints(make_model_year):
    for _,row in make_model_year.iterrows():
        make_complaints = []
        print(f'Downloading data for {row['modelYear']} {row['make']} {row['model']}')
        complaints = get_complaints(row['make'],row['model'],row['modelYear'])
        if complaints:
            for c in complaints:
                c['make'] = row.get('make',None)
                c['model'] = row.get('model',None)
                c['modelYear'] = row.get('modelYear',None)
                c['products'] = json.dumps(c.get('products',{}))
                make_complaints.append(c)
        make_df = pd.DataFrame(make_complaints)
        db = pg_connect()
        if len(make_df) > 0:
            make_df.to_sql('complaints',db,index=False,if_exists='append')
        # update complaints download tracker
        with db.connect() as connection:
            query = text('''
            update complaints_download_tracker
            set complaints_last_updated = current_timestamp, total_complaints = :w
            where "modelYear" = :x and make = :y and model = :z
            ''')
            connection.execute(query,{'w':make_df.shape[0],'x': str(row['modelYear']),'y':row['make'],'z':row['model']})
            connection.commit()
        db.dispose()
        # Done.
        print(f'Complaint data for {row['modelYear']} {row['make']} {row['model']} updated: {make_df.shape[0]} total complaints')
        time.sleep(1)

make_model_year = pg_query(f""" 
(
    select 
        * 
    from complaints_download_tracker
    where make='TESLA' and "modelYear"::int >= extract(year from current_date) - 5
    and extract('days' from current_timestamp - complaints_last_updated) > 0
)
union all
(
    select
        "modelYear",
        "make",
        "model",
        "complaints_last_updated",
        "total_complaints"
    from (
        select 
            *,
            random()
        from complaints_download_tracker
        where make !='TESLA'
        and "modelYear"::int >= extract(year from current_date) - 5
        and extract('days' from current_timestamp - complaints_last_updated) > 3
    ) tbl
    order by random() limit 400
)
""")
if len(make_model_year) > 0:
    update_complaints(make_model_year)
print(f"Stale data randomly updated.")


pg_execute("drop table if exists complaints_backup")
pg_execute("""
create table complaints_backup as
select distinct on ("odiNumber")
    *
from complaints 
""")
pg_execute("delete from complaints")
pg_execute('insert into complaints select * from complaints_backup')
pg_execute('drop table complaints_backup')

print("Complaints data table cleaned.")

##########################
# Update car_sales
##########################
car_sales = pd.read_csv('car_sales.csv')
import re
car_sales['Automaker'] = car_sales.Automaker.apply(lambda x: re.sub(',$','',x).split(','))

complaints = []
for _,row in car_sales.iterrows():
    complain = 0
    for maker in row['Automaker']:
        c = pg_query(f""" 
select count(*) from complaints where make = '{maker}'
and "modelYear" = '{row['Year']}'
""")
        complain = complain + c['count'][0] 

    complaints.append(complain)

car_sales['complaints'] = complaints
car_sales['percentage'] = car_sales['complaints']/car_sales['Sold Autos']
car_sales = car_sales[car_sales['percentage']>0]

unparsed = []
for _,row in car_sales.iterrows():
    for make in row['Automaker']:
        unparsed.append({
            'parent': row['Umbrella'],
            'make': make,
            'modelYear': row['Year'],
            'parent_autos_sold': row['Sold Autos'],
            'world_rank': row['World Rank'],
            'parent_modelYear_complaints': row['complaints'],
            'parent_modelYear_percentage': row['percentage']
        })

df = pd.DataFrame(unparsed)
# Save to database
db = pg_connect()
df.to_sql('car_sales',db,index=False,if_exists='replace')
db.dispose()

pg_execute("""
UPDATE car_sales
SET make = REPLACE(make, 'MERCEDES BENZ', 'MERCEDES-BENZ')
WHERE make = 'MERCEDES BENZ';
""")
# Out:
# complaints_model_download_tracker updated
# Downloading SHORELAND'R 9999 models
# []
# 9999 SHORELAND'R models updated: 0 new models
# Downloading RAYBESTOS 9999 models
# []
# 9999 RAYBESTOS models updated: 0 new models
# Downloading LAZY DAZE 9999 models
# []
# 9999 LAZY DAZE models updated: 0 new models
# Downloading UTILITY 9999 models
# []
# 9999 UTILITY models updated: 0 new models
# Downloading RIVERSIDE 9999 models
# []
# 9999 RIVERSIDE models updated: 0 new models
# Downloading CNG. 9999 models
# []
# 9999 CNG. models updated: 0 new models
# Downloading LOTUS 9999 models
# []
# 9999 LOTUS models updated: 0 new models
# Downloading WIDETRACK 9999 models
# []
# 9999 WIDETRACK models updated: 0 new models
# Downloading GEM 9999 models
# []
# 9999 GEM models updated: 0 new models
# Downloading CONDERE 9999 models
# []
# 9999 CONDERE models updated: 0 new models
# Downloading GEO 9999 models
# []
# 9999 GEO models updated: 0 new models
# Downloading RIKEN 9999 models
# []
# 9999 RIKEN models updated: 0 new models
# Downloading GENERAL MOTORS 9999 models
# []
# 9999 GENERAL MOTORS models updated: 0 new models
# Downloading NORSTAR 9999 models
# []
# 9999 NORSTAR models updated: 0 new models
# Downloading TBD 9999 models
# []
# 9999 TBD models updated: 0 new models
# Downloading DUTCHMAN 9999 models
# []
# 9999 DUTCHMAN models updated: 0 new models
# Downloading NATIONAL 9999 models
# []
# 9999 NATIONAL models updated: 0 new models
# Downloading EARLY DEVELOPMENT 9999 models
# []
# 9999 EARLY DEVELOPMENT models updated: 0 new models
# Downloading DELCO 9999 models
# []
# 9999 DELCO models updated: 0 new models
# Downloading YELLOWSTONE 9999 models
# []
# 9999 YELLOWSTONE models updated: 0 new models
# Downloading SILVERLITE 9999 models
# []
# 9999 SILVERLITE models updated: 0 new models
# Downloading EAGLE 9999 models
# []
# 9999 EAGLE models updated: 0 new models
# Downloading NISSAN 9999 models
# []
# 9999 NISSAN models updated: 0 new models
# Downloading ZAP 9999 models
# []
# 9999 ZAP models updated: 0 new models
# Downloading OSHKOSH 9999 models
# []
# 9999 OSHKOSH models updated: 0 new models
# Downloading U HAUL 9999 models
# []
# 9999 U HAUL models updated: 0 new models
# Downloading PETERBILT 9999 models
# []
# 9999 PETERBILT models updated: 0 new models
# Downloading GMC 9999 models
# []
# 9999 GMC models updated: 0 new models
# Downloading RV 9999 models
# []
# 9999 RV models updated: 0 new models
# Downloading PLEASURE WAY 9999 models
# []
# 9999 PLEASURE WAY models updated: 0 new models
# Downloading CRANE CARRIER 9999 models
# []
# 9999 CRANE CARRIER models updated: 0 new models
# Downloading MERCEDES BENZ 9999 models
# []
# 9999 MERCEDES BENZ models updated: 0 new models
# Downloading HAUL-MASTER 9999 models
# []
# 9999 HAUL-MASTER models updated: 0 new models
# Downloading KBC 9999 models
# []
# 9999 KBC models updated: 0 new models
# Downloading TRAVEL SAFETY 9999 models
# []
# 9999 TRAVEL SAFETY models updated: 0 new models
# Downloading WESTERN STAR 9999 models
# []
# 9999 WESTERN STAR models updated: 0 new models
# Downloading GLOBAL 9999 models
# []
# 9999 GLOBAL models updated: 0 new models
# Downloading YOKOHAMA 9999 models
# []
# 9999 YOKOHAMA models updated: 0 new models
# Downloading LES SCHWAB 9999 models
# []
# 9999 LES SCHWAB models updated: 0 new models
# Downloading MIRAGE 9999 models
# []
# 9999 MIRAGE models updated: 0 new models
# Downloading 6504510106 9999 models
# []
# 9999 6504510106 models updated: 0 new models
# Downloading AM GENERAL 9999 models
# []
# 9999 AM GENERAL models updated: 0 new models
# Downloading VIKING 9999 models
# []
# 9999 VIKING models updated: 0 new models
# Downloading GOERLICH 9999 models
# []
# 9999 GOERLICH models updated: 0 new models
# Downloading ACURA 9999 models
# []
# 9999 ACURA models updated: 0 new models
# Downloading ELDORADO 9999 models
# []
# 9999 ELDORADO models updated: 0 new models
# Downloading MCI 9999 models
# []
# 9999 MCI models updated: 0 new models
# Downloading UNITED TRAILERS 9999 models
# []
# 9999 UNITED TRAILERS models updated: 0 new models
# Downloading STP 9999 models
# []
# 9999 STP models updated: 0 new models
# Downloading TRAVELEZE 9999 models
# []
# 9999 TRAVELEZE models updated: 0 new models
# Downloading BENDIX 9999 models
# []
# 9999 BENDIX models updated: 0 new models
# Downloading COLT 9999 models
# []
# 9999 COLT models updated: 0 new models
# Downloading SCOOTER 9999 models
# []
# 9999 SCOOTER models updated: 0 new models
# Downloading CROWN 9999 models
# []
# 9999 CROWN models updated: 0 new models
# Downloading MITSUBISHI 9999 models
# []
# 9999 MITSUBISHI models updated: 0 new models
# Downloading DUCATI 9999 models
# []
# 9999 DUCATI models updated: 0 new models
# Downloading ALINER 9999 models
# []
# 9999 ALINER models updated: 0 new models
# Downloading PILGRIM 9999 models
# []
# 9999 PILGRIM models updated: 0 new models
# Downloading TRAILMASTER 9999 models
# []
# 9999 TRAILMASTER models updated: 0 new models
# Downloading PREVOST 9999 models
# []
# 9999 PREVOST models updated: 0 new models
# Downloading ROYAL 9999 models
# []
# 9999 ROYAL models updated: 0 new models
# Downloading KENWOOD 9999 models
# []
# 9999 KENWOOD models updated: 0 new models
# Downloading TRANSPORT TRAILER 9999 models
# []
# 9999 TRANSPORT TRAILER models updated: 0 new models
# Downloading VOLKSWAGEN 9999 models
# []
# 9999 VOLKSWAGEN models updated: 0 new models
# Downloading GEORGIE BOY 9999 models
# []
# 9999 GEORGIE BOY models updated: 0 new models
# Downloading SUNLITE 9999 models
# []
# 9999 SUNLITE models updated: 0 new models
# Downloading POLARIS 9999 models
# []
# 9999 POLARIS models updated: 0 new models
# Downloading SUPERIOR 9999 models
# []
# 9999 SUPERIOR models updated: 0 new models
# Downloading COKER 9999 models
# []
# 9999 COKER models updated: 0 new models
# Downloading FREIGHTLINER 9999 models
# []
# 9999 FREIGHTLINER models updated: 0 new models
# Downloading MAXIM 9999 models
# []
# 9999 MAXIM models updated: 0 new models
# Downloading UNKNOWN MANUFACTURER 9999 models
# []
# 9999 UNKNOWN MANUFACTURER models updated: 0 new models
# Downloading JOHN DEERE 9999 models
# []
# 9999 JOHN DEERE models updated: 0 new models
# Downloading NATIONAL O-RING 9999 models
# []
# 9999 NATIONAL O-RING models updated: 0 new models
# Downloading STRICK 9999 models
# []
# 9999 STRICK models updated: 0 new models
# Downloading FIAT 9999 models
# []
# 9999 FIAT models updated: 0 new models
# Downloading HONDA 9999 models
# []
# 9999 HONDA models updated: 0 new models
# Downloading JEEP 9999 models
# []
# 9999 JEEP models updated: 0 new models
# Downloading CHANCE 9999 models
# []
# 9999 CHANCE models updated: 0 new models
# Downloading GENERAL TRAILER 9999 models
# []
# 9999 GENERAL TRAILER models updated: 0 new models
# Downloading TRAVEL MASTER 9999 models
# []
# 9999 TRAVEL MASTER models updated: 0 new models
# Downloading CONVENTIONAL 9999 models
# []
# 9999 CONVENTIONAL models updated: 0 new models
# Downloading ROADRUNNER 300CC 9999 models
# []
# 9999 ROADRUNNER 300CC models updated: 0 new models
# Downloading BUELL 9999 models
# []
# 9999 BUELL models updated: 0 new models
# Downloading WHITE GMC 9999 models
# []
# 9999 WHITE GMC models updated: 0 new models
# Downloading SUZUKI 9999 models
# []
# 9999 SUZUKI models updated: 0 new models
# Downloading BEAVER 9999 models
# []
# 9999 BEAVER models updated: 0 new models
# Downloading TRUCK TRAILER 9999 models
# []
# 9999 TRUCK TRAILER models updated: 0 new models
# Downloading UNKNOWN 9999 models
# []
# 9999 UNKNOWN models updated: 0 new models
# Downloading FOREST RIVER 9999 models
# []
# 9999 FOREST RIVER models updated: 0 new models
# Downloading U-HAUL 9999 models
# []
# 9999 U-HAUL models updated: 0 new models
# Downloading CASITA 9999 models
# []
# 9999 CASITA models updated: 0 new models
# Downloading CASITA ENTERPRISES 9999 models
# []
# 9999 CASITA ENTERPRISES models updated: 0 new models
# Downloading THOROUGHBRED TRAILERS 9999 models
# []
# 9999 THOROUGHBRED TRAILERS models updated: 0 new models
# Downloading MOTORCYCLE 9999 models
# []
# 9999 MOTORCYCLE models updated: 0 new models
# Downloading VANGUARD 9999 models
# []
# 9999 VANGUARD models updated: 0 new models
# Downloading BINTELLI 2024 models
# [{'modelYear': '2024', 'make': 'BINTELLI', 'model': 'BEYOND'}]
# 2024 BINTELLI models updated: 1 new models
# Downloading ABC 9999 models
# []
# 9999 ABC models updated: 0 new models
# Downloading JENSEN 9999 models
# []
# 9999 JENSEN models updated: 0 new models
# Downloading COACHMEN 9999 models
# []
# 9999 COACHMEN models updated: 0 new models
# Downloading GILLIG 9999 models
# []
# 9999 GILLIG models updated: 0 new models
# Downloading APACHE 9999 models
# []
# 9999 APACHE models updated: 0 new models
# Downloading THOMAS 9999 models
# Attempt 1 timed out. Retrying...
# []
# 9999 THOMAS models updated: 0 new models
# Downloading ISUZU 9999 models
# []
# 9999 ISUZU models updated: 0 new models
# Downloading ROADTREK 9999 models
# []
# 9999 ROADTREK models updated: 0 new models
# Downloading JOHNSON 9999 models
# []
# 9999 JOHNSON models updated: 0 new models
# Downloading THOR MOTOR COACH 9999 models
# []
# 9999 THOR MOTOR COACH models updated: 0 new models
# Downloading KING OF THE ROAD 9999 models
# []
# 9999 KING OF THE ROAD models updated: 0 new models
# Downloading EZ LOADER 9999 models
# []
# 9999 EZ LOADER models updated: 0 new models
# Downloading SHELBY 9999 models
# []
# 9999 SHELBY models updated: 0 new models
# Downloading NEWMAR 9999 models
# []
# 9999 NEWMAR models updated: 0 new models
# Downloading ARROW 9999 models
# []
# 9999 ARROW models updated: 0 new models
# Downloading MERCEDES-BENZ 9999 models
# []
# 9999 MERCEDES-BENZ models updated: 0 new models
# Downloading HARVEY TRAILER 9999 models
# []
# 9999 HARVEY TRAILER models updated: 0 new models
# Downloading ITASCA 9999 models
# []
# 9999 ITASCA models updated: 0 new models
# Downloading CADILLAC 9999 models
# []
# 9999 CADILLAC models updated: 0 new models
# Downloading POWERTRAIN 9999 models
# []
# 9999 POWERTRAIN models updated: 0 new models
# Downloading TIFFIN 9999 models
# []
# 9999 TIFFIN models updated: 0 new models
# Downloading KAWASAKI 9999 models
# []
# 9999 KAWASAKI models updated: 0 new models
# Downloading SAAB 9999 models
# []
# 9999 SAAB models updated: 0 new models
# Downloading KENWORTH 9999 models
# []
# 9999 KENWORTH models updated: 0 new models
# Downloading YAMAHA 9999 models
# []
# 9999 YAMAHA models updated: 0 new models
# Downloading DIE HARD 9999 models
# []
# 9999 DIE HARD models updated: 0 new models
# Downloading BOAT TRAILER 9999 models
# []
# 9999 BOAT TRAILER models updated: 0 new models
# Duplicates removed from complaints_models
# complaints_models table cleaned
# complaints_download_tracker updated
# Downloading data for 2024 BINTELLI BEYOND
# Complaint data for 2024 BINTELLI BEYOND updated: 1 total complaints
# Stale data randomly updated.
# Complaints data table cleaned.
# 'done'
